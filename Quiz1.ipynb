# %%
A= [3,6,88,34,1,77,98,44]

# %%
def bubbleSort(array):  
    for i in range(len(array)):
        print('i=',i,end=' ')
        for j in range(0, len(array) - i - 1):
            print('\t j=',j)
            if array[j] > array[j + 1]:
                temp = array[j]
                array[j] = array[j+1]
                array[j+1] = temp
                print()
                print(f'Pushing >>>> {temp}')
                print()
            
            print(f'Data : {array}')

bubbleSort(A)

print('Sorted Array in Ascending Order:')
print(A)
# Out:
# i= 0 	 j= 0
# Data : [1, 3, 6, 34, 44, 77, 88, 98]
# 	 j= 1
# Data : [1, 3, 6, 34, 44, 77, 88, 98]
# 	 j= 2
# Data : [1, 3, 6, 34, 44, 77, 88, 98]
# 	 j= 3
# Data : [1, 3, 6, 34, 44, 77, 88, 98]
# 	 j= 4
# Data : [1, 3, 6, 34, 44, 77, 88, 98]
# 	 j= 5
# Data : [1, 3, 6, 34, 44, 77, 88, 98]
# 	 j= 6
# Data : [1, 3, 6, 34, 44, 77, 88, 98]
# i= 1 	 j= 0
# Data : [1, 3, 6, 34, 44, 77, 88, 98]
# 	 j= 1
# Data : [1, 3, 6, 34, 44, 77, 88, 98]
# 	 j= 2
# Data : [1, 3, 6, 34, 44, 77, 88, 98]
# 	 j= 3
# Data : [1, 3, 6, 34, 44, 77, 88, 98]
# 	 j= 4
# Data : [1, 3, 6, 34, 44, 77, 88, 98]
# 	 j= 5
# Data : [1, 3, 6, 34, 44, 77, 88, 98]
# i= 2 	 j= 0
# Data : [1, 3, 6, 34, 44, 77, 88, 98]
# 	 j= 1
# Data : [1, 3, 6, 34, 44, 77, 88, 98]
# 	 j= 2
# Data : [1, 3, 6, 34, 44, 77, 88, 98]
# 	 j= 3
# Data : [1, 3, 6, 34, 44, 77, 88, 98]
# 	 j= 4
# Data : [1, 3, 6, 34, 44, 77, 88, 98]
# i= 3 	 j= 0
# Data : [1, 3, 6, 34, 44, 77, 88, 98]
# 	 j= 1
# Data : [1, 3, 6, 34, 44, 77, 88, 98]
# 	 j= 2
# Data : [1, 3, 6, 34, 44, 77, 88, 98]
# 	 j= 3
# Data : [1, 3, 6, 34, 44, 77, 88, 98]
# i= 4 	 j= 0
# Data : [1, 3, 6, 34, 44, 77, 88, 98]
# 	 j= 1
# Data : [1, 3, 6, 34, 44, 77, 88, 98]
# 	 j= 2
# Data : [1, 3, 6, 34, 44, 77, 88, 98]
# i= 5 	 j= 0
# Data : [1, 3, 6, 34, 44, 77, 88, 98]
# 	 j= 1
# Data : [1, 3, 6, 34, 44, 77, 88, 98]
# i= 6 	 j= 0
# Data : [1, 3, 6, 34, 44, 77, 88, 98]
# i= 7 Sorted Array in Ascending Order:
# [1, 3, 6, 34, 44, 77, 88, 98]

# %%
def quick_sort(array):
    print(f'Array : {array}')
    length = len(array)
    if length <=1:
        print('No sorting needed breaking logic')
        return array
    else:
        pivot = array.pop()
        print(f'Pivot is now {pivot}')
        
    items_greater = []
    items_lower = []
    
    for item in array:
        
        if item > pivot :
            items_greater.append(item)
            print(f'{item}  is greater than {pivot}')
            print(f'List of greater than {pivot} itmes : {items_greater}')
        else:
            items_lower.append(item)
            print(f'{item}  is smaller than {pivot}')
            print(f'List of lower than {pivot} itmes : {items_lower}')
    print('----------------------------------')
    print(f'List of greater than {pivot} itmes : {items_greater}')
    print(f'List of lower than {pivot} itmes : {items_lower}')
    print('----------------------------------')
    
    print(quick_sort(items_lower) + [pivot] + quick_sort(items_greater))
    return quick_sort(items_lower) + [pivot] + quick_sort(items_greater)
             
        
        
    
result = quick_sort(A)
print(result)
# Out:
# Array : [1, 3, 6, 34, 44, 77, 88, 98]
# Pivot is now 98
# 1  is smaller than 98
# List of lower than 98 itmes : [1]
# 3  is smaller than 98
# List of lower than 98 itmes : [1, 3]
# 6  is smaller than 98
# List of lower than 98 itmes : [1, 3, 6]
# 34  is smaller than 98
# List of lower than 98 itmes : [1, 3, 6, 34]
# 44  is smaller than 98
# List of lower than 98 itmes : [1, 3, 6, 34, 44]
# 77  is smaller than 98
# List of lower than 98 itmes : [1, 3, 6, 34, 44, 77]
# 88  is smaller than 98
# List of lower than 98 itmes : [1, 3, 6, 34, 44, 77, 88]
# ----------------------------------
# List of greater than 98 itmes : []
# List of lower than 98 itmes : [1, 3, 6, 34, 44, 77, 88]
# ----------------------------------
# Array : [1, 3, 6, 34, 44, 77, 88]
# Pivot is now 88
# 1  is smaller than 88
# List of lower than 88 itmes : [1]
# 3  is smaller than 88
# List of lower than 88 itmes : [1, 3]
# 6  is smaller than 88
# List of lower than 88 itmes : [1, 3, 6]
# 34  is smaller than 88
# List of lower than 88 itmes : [1, 3, 6, 34]
# 44  is smaller than 88
# List of lower than 88 itmes : [1, 3, 6, 34, 44]
# 77  is smaller than 88
# List of lower than 88 itmes : [1, 3, 6, 34, 44, 77]
# ----------------------------------
# List of greater than 88 itmes : []
# List of lower than 88 itmes : [1, 3, 6, 34, 44, 77]
# ----------------------------------
# Array : [1, 3, 6, 34, 44, 77]
# Pivot is now 77
# 1  is smaller than 77
# List of lower than 77 itmes : [1]
# 3  is smaller than 77
# List of lower than 77 itmes : [1, 3]
# 6  is smaller than 77
# List of lower than 77 itmes : [1, 3, 6]
# 34  is smaller than 77
# List of lower than 77 itmes : [1, 3, 6, 34]
# 44  is smaller than 77
# List of lower than 77 itmes : [1, 3, 6, 34, 44]
# ----------------------------------
# List of greater than 77 itmes : []
# List of lower than 77 itmes : [1, 3, 6, 34, 44]
# ----------------------------------
# Array : [1, 3, 6, 34, 44]
# Pivot is now 44
# 1  is smaller than 44
# List of lower than 44 itmes : [1]
# 3  is smaller than 44
# List of lower than 44 itmes : [1, 3]
# 6  is smaller than 44
# List of lower than 44 itmes : [1, 3, 6]
# 34  is smaller than 44
# List of lower than 44 itmes : [1, 3, 6, 34]
# ----------------------------------
# List of greater than 44 itmes : []
# List of lower than 44 itmes : [1, 3, 6, 34]
# ----------------------------------
# Array : [1, 3, 6, 34]
# Pivot is now 34
# 1  is smaller than 34
# List of lower than 34 itmes : [1]
# 3  is smaller than 34
# List of lower than 34 itmes : [1, 3]
# 6  is smaller than 34
# List of lower than 34 itmes : [1, 3, 6]
# ----------------------------------
# List of greater than 34 itmes : []
# List of lower than 34 itmes : [1, 3, 6]
# ----------------------------------
# Array : [1, 3, 6]
# Pivot is now 6
# 1  is smaller than 6
# List of lower than 6 itmes : [1]
# 3  is smaller than 6
# List of lower than 6 itmes : [1, 3]
# ----------------------------------
# List of greater than 6 itmes : []
# List of lower than 6 itmes : [1, 3]
# ----------------------------------
# Array : [1, 3]
# Pivot is now 3
# 1  is smaller than 3
# List of lower than 3 itmes : [1]
# ----------------------------------
# List of greater than 3 itmes : []
# List of lower than 3 itmes : [1]
# ----------------------------------
# Array : [1]
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# [1, 3]
# Array : [1]
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# [1, 3, 6]
# Array : [1]
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# [1, 6, 34]
# Array : [1, 3]
# Pivot is now 3
# 1  is smaller than 3
# List of lower than 3 itmes : [1]
# ----------------------------------
# List of greater than 3 itmes : []
# List of lower than 3 itmes : [1]
# ----------------------------------
# Array : [1]
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# [1, 3]
# Array : [1]
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# [1, 3, 34, 44]
# Array : [1, 3, 6]
# Pivot is now 6
# 1  is smaller than 6
# List of lower than 6 itmes : [1]
# 3  is smaller than 6
# List of lower than 6 itmes : [1, 3]
# ----------------------------------
# List of greater than 6 itmes : []
# List of lower than 6 itmes : [1, 3]
# ----------------------------------
# Array : [1, 3]
# Pivot is now 3
# 1  is smaller than 3
# List of lower than 3 itmes : [1]
# ----------------------------------
# List of greater than 3 itmes : []
# List of lower than 3 itmes : [1]
# ----------------------------------
# Array : [1]
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# [1, 3]
# Array : [1]
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# [1, 3, 6]
# Array : [1]
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# [1, 6, 44, 77]
# Array : [1, 3, 6, 34]
# Pivot is now 34
# 1  is smaller than 34
# List of lower than 34 itmes : [1]
# 3  is smaller than 34
# List of lower than 34 itmes : [1, 3]
# 6  is smaller than 34
# List of lower than 34 itmes : [1, 3, 6]
# ----------------------------------
# List of greater than 34 itmes : []
# List of lower than 34 itmes : [1, 3, 6]
# ----------------------------------
# Array : [1, 3, 6]
# Pivot is now 6
# 1  is smaller than 6
# List of lower than 6 itmes : [1]
# 3  is smaller than 6
# List of lower than 6 itmes : [1, 3]
# ----------------------------------
# List of greater than 6 itmes : []
# List of lower than 6 itmes : [1, 3]
# ----------------------------------
# Array : [1, 3]
# Pivot is now 3
# 1  is smaller than 3
# List of lower than 3 itmes : [1]
# ----------------------------------
# List of greater than 3 itmes : []
# List of lower than 3 itmes : [1]
# ----------------------------------
# Array : [1]
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# [1, 3]
# Array : [1]
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# [1, 3, 6]
# Array : [1]
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# [1, 6, 34]
# Array : [1, 3]
# Pivot is now 3
# 1  is smaller than 3
# List of lower than 3 itmes : [1]
# ----------------------------------
# List of greater than 3 itmes : []
# List of lower than 3 itmes : [1]
# ----------------------------------
# Array : [1]
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# [1, 3]
# Array : [1]
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# [1, 3, 34, 77, 88]
# Array : [1, 3, 6, 34, 44]
# Pivot is now 44
# 1  is smaller than 44
# List of lower than 44 itmes : [1]
# 3  is smaller than 44
# List of lower than 44 itmes : [1, 3]
# 6  is smaller than 44
# List of lower than 44 itmes : [1, 3, 6]
# 34  is smaller than 44
# List of lower than 44 itmes : [1, 3, 6, 34]
# ----------------------------------
# List of greater than 44 itmes : []
# List of lower than 44 itmes : [1, 3, 6, 34]
# ----------------------------------
# Array : [1, 3, 6, 34]
# Pivot is now 34
# 1  is smaller than 34
# List of lower than 34 itmes : [1]
# 3  is smaller than 34
# List of lower than 34 itmes : [1, 3]
# 6  is smaller than 34
# List of lower than 34 itmes : [1, 3, 6]
# ----------------------------------
# List of greater than 34 itmes : []
# List of lower than 34 itmes : [1, 3, 6]
# ----------------------------------
# Array : [1, 3, 6]
# Pivot is now 6
# 1  is smaller than 6
# List of lower than 6 itmes : [1]
# 3  is smaller than 6
# List of lower than 6 itmes : [1, 3]
# ----------------------------------
# List of greater than 6 itmes : []
# List of lower than 6 itmes : [1, 3]
# ----------------------------------
# Array : [1, 3]
# Pivot is now 3
# 1  is smaller than 3
# List of lower than 3 itmes : [1]
# ----------------------------------
# List of greater than 3 itmes : []
# List of lower than 3 itmes : [1]
# ----------------------------------
# Array : [1]
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# [1, 3]
# Array : [1]
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# [1, 3, 6]
# Array : [1]
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# [1, 6, 34]
# Array : [1, 3]
# Pivot is now 3
# 1  is smaller than 3
# List of lower than 3 itmes : [1]
# ----------------------------------
# List of greater than 3 itmes : []
# List of lower than 3 itmes : [1]
# ----------------------------------
# Array : [1]
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# [1, 3]
# Array : [1]
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# [1, 3, 34, 44]
# Array : [1, 3, 6]
# Pivot is now 6
# 1  is smaller than 6
# List of lower than 6 itmes : [1]
# 3  is smaller than 6
# List of lower than 6 itmes : [1, 3]
# ----------------------------------
# List of greater than 6 itmes : []
# List of lower than 6 itmes : [1, 3]
# ----------------------------------
# Array : [1, 3]
# Pivot is now 3
# 1  is smaller than 3
# List of lower than 3 itmes : [1]
# ----------------------------------
# List of greater than 3 itmes : []
# List of lower than 3 itmes : [1]
# ----------------------------------
# Array : [1]
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# [1, 3]
# Array : [1]
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# [1, 3, 6]
# Array : [1]
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# [1, 6, 44, 88, 98]
# Array : [1, 3, 6, 34, 44, 77]
# Pivot is now 77
# 1  is smaller than 77
# List of lower than 77 itmes : [1]
# 3  is smaller than 77
# List of lower than 77 itmes : [1, 3]
# 6  is smaller than 77
# List of lower than 77 itmes : [1, 3, 6]
# 34  is smaller than 77
# List of lower than 77 itmes : [1, 3, 6, 34]
# 44  is smaller than 77
# List of lower than 77 itmes : [1, 3, 6, 34, 44]
# ----------------------------------
# List of greater than 77 itmes : []
# List of lower than 77 itmes : [1, 3, 6, 34, 44]
# ----------------------------------
# Array : [1, 3, 6, 34, 44]
# Pivot is now 44
# 1  is smaller than 44
# List of lower than 44 itmes : [1]
# 3  is smaller than 44
# List of lower than 44 itmes : [1, 3]
# 6  is smaller than 44
# List of lower than 44 itmes : [1, 3, 6]
# 34  is smaller than 44
# List of lower than 44 itmes : [1, 3, 6, 34]
# ----------------------------------
# List of greater than 44 itmes : []
# List of lower than 44 itmes : [1, 3, 6, 34]
# ----------------------------------
# Array : [1, 3, 6, 34]
# Pivot is now 34
# 1  is smaller than 34
# List of lower than 34 itmes : [1]
# 3  is smaller than 34
# List of lower than 34 itmes : [1, 3]
# 6  is smaller than 34
# List of lower than 34 itmes : [1, 3, 6]
# ----------------------------------
# List of greater than 34 itmes : []
# List of lower than 34 itmes : [1, 3, 6]
# ----------------------------------
# Array : [1, 3, 6]
# Pivot is now 6
# 1  is smaller than 6
# List of lower than 6 itmes : [1]
# 3  is smaller than 6
# List of lower than 6 itmes : [1, 3]
# ----------------------------------
# List of greater than 6 itmes : []
# List of lower than 6 itmes : [1, 3]
# ----------------------------------
# Array : [1, 3]
# Pivot is now 3
# 1  is smaller than 3
# List of lower than 3 itmes : [1]
# ----------------------------------
# List of greater than 3 itmes : []
# List of lower than 3 itmes : [1]
# ----------------------------------
# Array : [1]
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# [1, 3]
# Array : [1]
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# [1, 3, 6]
# Array : [1]
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# [1, 6, 34]
# Array : [1, 3]
# Pivot is now 3
# 1  is smaller than 3
# List of lower than 3 itmes : [1]
# ----------------------------------
# List of greater than 3 itmes : []
# List of lower than 3 itmes : [1]
# ----------------------------------
# Array : [1]
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# [1, 3]
# Array : [1]
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# [1, 3, 34, 44]
# Array : [1, 3, 6]
# Pivot is now 6
# 1  is smaller than 6
# List of lower than 6 itmes : [1]
# 3  is smaller than 6
# List of lower than 6 itmes : [1, 3]
# ----------------------------------
# List of greater than 6 itmes : []
# List of lower than 6 itmes : [1, 3]
# ----------------------------------
# Array : [1, 3]
# Pivot is now 3
# 1  is smaller than 3
# List of lower than 3 itmes : [1]
# ----------------------------------
# List of greater than 3 itmes : []
# List of lower than 3 itmes : [1]
# ----------------------------------
# Array : [1]
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# [1, 3]
# Array : [1]
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# [1, 3, 6]
# Array : [1]
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# [1, 6, 44, 77]
# Array : [1, 3, 6, 34]
# Pivot is now 34
# 1  is smaller than 34
# List of lower than 34 itmes : [1]
# 3  is smaller than 34
# List of lower than 34 itmes : [1, 3]
# 6  is smaller than 34
# List of lower than 34 itmes : [1, 3, 6]
# ----------------------------------
# List of greater than 34 itmes : []
# List of lower than 34 itmes : [1, 3, 6]
# ----------------------------------
# Array : [1, 3, 6]
# Pivot is now 6
# 1  is smaller than 6
# List of lower than 6 itmes : [1]
# 3  is smaller than 6
# List of lower than 6 itmes : [1, 3]
# ----------------------------------
# List of greater than 6 itmes : []
# List of lower than 6 itmes : [1, 3]
# ----------------------------------
# Array : [1, 3]
# Pivot is now 3
# 1  is smaller than 3
# List of lower than 3 itmes : [1]
# ----------------------------------
# List of greater than 3 itmes : []
# List of lower than 3 itmes : [1]
# ----------------------------------
# Array : [1]
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# [1, 3]
# Array : [1]
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# [1, 3, 6]
# Array : [1]
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# [1, 6, 34]
# Array : [1, 3]
# Pivot is now 3
# 1  is smaller than 3
# List of lower than 3 itmes : [1]
# ----------------------------------
# List of greater than 3 itmes : []
# List of lower than 3 itmes : [1]
# ----------------------------------
# Array : [1]
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# [1, 3]
# Array : [1]
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# Array : []
# No sorting needed breaking logic
# [1, 3, 34, 77, 98]
